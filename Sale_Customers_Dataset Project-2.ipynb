# %%
import pandas as pd

# %%
df=pd.read_csv("/Users/Vibhanshu/Desktop/MSc. Data Science/Python/Assignment/Sale_Customers.csv")
df
# Out:
#      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]

# %%
df.shape
# Out:
# (200, 5)

# %%
df.describe()
# Out:
#        CustomerID         Age  Annual Income (k$)  Spending Score (1-100)
# count  200.000000  200.000000          200.000000              200.000000
# mean   100.500000   38.850000           60.560000               50.200000
# std     57.879185   13.969007           26.264721               25.823522
# min      1.000000   18.000000           15.000000                1.000000
# 25%     50.750000   28.750000           41.500000               34.750000
# 50%    100.500000   36.000000           61.500000               50.000000
# 75%    150.250000   49.000000           78.000000               73.000000
# max    200.000000   70.000000          137.000000               99.000000

# %%
df.size
# Out:
# 1000

# %%
df.describe().T
# Out:
#                         count    mean        std   min    25%    50%     75%  \
# CustomerID              200.0  100.50  57.879185   1.0  50.75  100.5  150.25
# Age                     200.0   38.85  13.969007  18.0  28.75   36.0   49.00
# Annual Income (k$)      200.0   60.56  26.264721  15.0  41.50   61.5   78.00
# Spending Score (1-100)  200.0   50.20  25.823522   1.0  34.75   50.0   73.00
#
#                           max
# CustomerID              200.0
# Age                      70.0
# Annual Income (k$)      137.0
# Spending Score (1-100)   99.0

# %%
print(df.to_string())
# Out:
#      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# 5             6  Female   22                  17                      76
# 6             7  Female   35                  18                       6
# 7             8  Female   23                  18                      94
# 8             9    Male   64                  19                       3
# 9            10  Female   30                  19                      72
# 10           11    Male   67                  19                      14
# 11           12  Female   35                  19                      99
# ...

# %%
#Data Cleaning
#Remove Rows
#Dropna method returns a new data frame and will not change the original.

new_df=df.dropna()

# %%
print(new_df.to_string())
# Out:
#      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# 5             6  Female   22                  17                      76
# 6             7  Female   35                  18                       6
# 7             8  Female   23                  18                      94
# 8             9    Male   64                  19                       3
# 9            10  Female   30                  19                      72
# 10           11    Male   67                  19                      14
# 11           12  Female   35                  19                      99
# ...

# %%
new_df.shape
# Out:
# (200, 5)

# %%
new_df.size
# Out:
# 1000

# %%
#Dropna(inplace=True) will not return a new dataframe but it will remove all rows containing null value from the original dataframe.
df.dropna(inplace=True)
print(df.to_string())
# Out:
#      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# 5             6  Female   22                  17                      76
# 6             7  Female   35                  18                       6
# 7             8  Female   23                  18                      94
# 8             9    Male   64                  19                       3
# 9            10  Female   30                  19                      72
# 10           11    Male   67                  19                      14
# 11           12  Female   35                  19                      99
# ...

# %%
#Replace Empty Values.
df=pd.read_csv("/Users/Vibhanshu/Desktop/MSc. Data Science/Python/Assignment/Sale_Customers.csv")

# %%
df.fillna(999,inplace=True)
print(df.to_string())
# Out:
#      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# 5             6  Female   22                  17                      76
# 6             7  Female   35                  18                       6
# 7             8  Female   23                  18                      94
# 8             9    Male   64                  19                       3
# 9            10  Female   30                  19                      72
# 10           11    Male   67                  19                      14
# 11           12  Female   35                  19                      99
# ...

# %%
df=pd.read_csv("/Users/Vibhanshu/Desktop/MSc. Data Science/Python/Assignment/Sale_Customers.csv")

# %%
df["Annual Income (k$)"].fillna(777,inplace=True)
print(df.to_string())
# Out:
#      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# 5             6  Female   22                  17                      76
# 6             7  Female   35                  18                       6
# 7             8  Female   23                  18                      94
# 8             9    Male   64                  19                       3
# 9            10  Female   30                  19                      72
# 10           11    Male   67                  19                      14
# 11           12  Female   35                  19                      99
# ...

# %%
#Replace using mean, median or mod.
#Mean
df=pd.read_csv("/Users/Vibhanshu/Desktop/MSc. Data Science/Python/Assignment/Sale_Customers.csv")
x=df["Annual Income (k$)"].mean()
df["Annual Income (k$)"].fillna(x,inplace=True)
print(df.to_string())
# Out:
#      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# 5             6  Female   22                  17                      76
# 6             7  Female   35                  18                       6
# 7             8  Female   23                  18                      94
# 8             9    Male   64                  19                       3
# 9            10  Female   30                  19                      72
# 10           11    Male   67                  19                      14
# 11           12  Female   35                  19                      99
# ...

# %%
#Replace using mean, median or mode.
#Median
df=pd.read_csv("/Users/Vibhanshu/Desktop/MSc. Data Science/Python/Assignment/Sale_Customers.csv")
x=df["Annual Income (k$)"].median()
df["Annual Income (k$)"].fillna(x,inplace=True)
print(df.to_string())
# Out:
#      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# 5             6  Female   22                  17                      76
# 6             7  Female   35                  18                       6
# 7             8  Female   23                  18                      94
# 8             9    Male   64                  19                       3
# 9            10  Female   30                  19                      72
# 10           11    Male   67                  19                      14
# 11           12  Female   35                  19                      99
# ...

# %%
#Mode
df=pd.read_csv("/Users/Vibhanshu/Desktop/MSc. Data Science/Python/Assignment/Sale_Customers.csv")
x=df["Annual Income (k$)"].mode()[0]
df["Annual Income (k$)"].fillna(x,inplace=True)
print(df.to_string())
# Out:
#      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# 5             6  Female   22                  17                      76
# 6             7  Female   35                  18                       6
# 7             8  Female   23                  18                      94
# 8             9    Male   64                  19                       3
# 9            10  Female   30                  19                      72
# 10           11    Male   67                  19                      14
# 11           12  Female   35                  19                      99
# ...

# %%
#Wrong Data
df=pd.read_csv("/Users/Vibhanshu/Desktop/MSc. Data Science/Python/Assignment/Sale_Customers.csv")
df.loc[7,"CustomerID "]=45
print(df.to_string())
# Out:
#      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)  CustomerID
# 0             1    Male   19                  15                      39          NaN
# 1             2    Male   21                  15                      81          NaN
# 2             3  Female   20                  16                       6          NaN
# 3             4  Female   23                  16                      77          NaN
# 4             5  Female   31                  17                      40          NaN
# 5             6  Female   22                  17                      76          NaN
# 6             7  Female   35                  18                       6          NaN
# 7             8  Female   23                  18                      94         45.0
# 8             9    Male   64                  19                       3          NaN
# 9            10  Female   30                  19                      72          NaN
# ...

# %%
for x in df.index:
    if df.loc[x,"CustomerID "]>120:
        df.loc[x,"CustomerID "]=120
print(df.to_string())
# Out:
#      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)  CustomerID
# 0             1    Male   19                  15                      39          NaN
# 1             2    Male   21                  15                      81          NaN
# 2             3  Female   20                  16                       6          NaN
# 3             4  Female   23                  16                      77          NaN
# 4             5  Female   31                  17                      40          NaN
# 5             6  Female   22                  17                      76          NaN
# 6             7  Female   35                  18                       6          NaN
# 7             8  Female   23                  18                      94         45.0
# 8             9    Male   64                  19                       3          NaN
# 9            10  Female   30                  19                      72          NaN
# ...

# %%
for x in df.index:
    if df.loc[x,"CustomerID "]>120:
        df.drop(x,inplace=True)
print(df.to_string())
# Out:
#      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)  CustomerID
# 0             1    Male   19                  15                      39          NaN
# 1             2    Male   21                  15                      81          NaN
# 2             3  Female   20                  16                       6          NaN
# 3             4  Female   23                  16                      77          NaN
# 4             5  Female   31                  17                      40          NaN
# 5             6  Female   22                  17                      76          NaN
# 6             7  Female   35                  18                       6          NaN
# 7             8  Female   23                  18                      94         45.0
# 8             9    Male   64                  19                       3          NaN
# 9            10  Female   30                  19                      72          NaN
# ...

# %%
#Removing Duplicates
df=pd.read_csv("/Users/Vibhanshu/Desktop/MSc. Data Science/Python/Assignment/Sale_Customers.csv")
print(df.to_string())
# Out:
#      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# 5             6  Female   22                  17                      76
# 6             7  Female   35                  18                       6
# 7             8  Female   23                  18                      94
# 8             9    Male   64                  19                       3
# 9            10  Female   30                  19                      72
# 10           11    Male   67                  19                      14
# 11           12  Female   35                  19                      99
# ...

# %%
df.drop_duplicates(inplace=True)
print(df.to_string())
# Out:
#      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# 5             6  Female   22                  17                      76
# 6             7  Female   35                  18                       6
# 7             8  Female   23                  18                      94
# 8             9    Male   64                  19                       3
# 9            10  Female   30                  19                      72
# 10           11    Male   67                  19                      14
# 11           12  Female   35                  19                      99
# ...

# %%
#Corelation
#corr() calculates the relationship b/w each column in the data set.
#The number varies from -1 to 1.
df=pd.read_csv("/Users/Vibhanshu/Desktop/MSc. Data Science/Python/Assignment/Sale_Customers.csv")
df.corr()
# Out:
# /var/folders/sp/2q6vh_9j0w1cb0bdct78zbm40000gn/T/ipykernel_4638/1836985535.py:5: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                         CustomerID       Age  Annual Income (k$)  \
# CustomerID                1.000000 -0.026763            0.977548
# Age                      -0.026763  1.000000           -0.012398
# Annual Income (k$)        0.977548 -0.012398            1.000000
# Spending Score (1-100)    0.013835 -0.327227            0.009903
#
#                         Spending Score (1-100)
# CustomerID                            0.013835
# Age                                  -0.327227
# Annual Income (k$)                    0.009903
# Spending Score (1-100)                1.000000
